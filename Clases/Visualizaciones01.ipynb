# %% [markdown]
# <a href="https://colab.research.google.com/github/williamvalenciaK/PowerBiPIT/blob/main/Clases/Visualizaciones01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table border=1 width='99%'>
# <tr>
# <td bgcolor='#004261'>
#
# # **<font color="#FFFFFF">  🗹  MÓDULO 01.- Visualizaciones básicas</font>**
#
# </td>
# </tr>
# </table>

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# [Componente redistribuible del motor de base de datos de Microsoft Access 2016](https://www.microsoft.com/es-es/download/details.aspx?id=54920)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# <table width='99%'>
# <tr>
# <td bgcolor='#FDD000'>
#
# ## **<font color="#000000"> ◉ ¿Qué son las funciones DAX?</font>**
#
# </td>
# </tr>
# </table>

# %% [markdown]
# Las **funciones DAX** (Data Analysis Expressions) en Power BI son un conjunto de funciones, operadores y constantes utilizados en fórmulas o expresiones para realizar cálculos y consultas avanzadas en Power BI.
#
# **DAX** es similar a las funciones de Excel, pero está específicamente diseñado para trabajar con datos relacionales y grandes volúmenes de datos.

# %% [markdown]
# ```
# Cantidad de unidades vendidas 1 = SUM(Factura[cnt_ven_fac_in])
# ```

# %% [markdown]
# ```
# Cantidad de unidades vendidas 2 = SUMX(Factura, Factura[cnt_ven_fac_in])
# ```

# %% [markdown]
# ```
# Cantidad de devoluciones 1 = SUM(Factura[cnt_ret_fac_in])
# ```

# %% [markdown]
# ```
# Cantidad de devoluciones 2 = SUMX(Factura, Factura[cnt_ret_fac_in])
# ```

# %% [markdown]
# <table width='99%'>
# <tr>
# <td bgcolor='#FDD000'>
#
# ## **<font color="#000000"> ◉ ¿Qué es un Ratio de Devoluciones?</font>**
#
# </td>
# </tr>
# </table>

# %% [markdown]
# Un ratio de devoluciones en Power BI es una métrica que se utiliza para medir la proporción de productos devueltos en relación con las ventas totales.
#
# Este ratio es importante para entender el desempeño de un negocio en términos de satisfacción del cliente y calidad del producto.
#
# Calcular el ratio de devoluciones puede ayudar a identificar problemas potenciales con productos específicos, proveedores o procesos de venta.

# %% [markdown]
# $$ Ratio\_de\_devoluciones = \frac{Total\_de\_devoluciones}{Total\_de\_ventas}$$

# %% [markdown]
# ```
# Ratio de devoluciones 1 = [Cantidad de devoluciones 1] / [Cantidad de unidades vendidas 1]
# ```

# %% [markdown]
# ```
# Ratio de devoluciones 2 = DIVIDE([Cantidad de devoluciones 1],  [Cantidad de unidades vendidas 1])
# ```

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# <table width='99%'>
# <tr>
# <td bgcolor='#FDD000'>
#
# ## **<font color="#000000"> ◉ Tabla calendario</font>**
#
# </td>
# </tr>
# </table>

# %% [markdown]
# Construir una tabla calendario en Power BI es una práctica esencial para realizar análisis de datos temporalmente explícitos.
#
# Una tabla calendario proporciona una serie de beneficios importantes que facilitan y mejoran la capacidad de análisis de datos relacionados con el tiempo.

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)
#
# ```
# # Tiene formato de código
# ```

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Calendario = CALENDARAUTO()
# ```

# %% [markdown]
# ```
# Año = YEAR(Calendario[Date])
# ```

# %% [markdown]
# ```
# Mes1 = FORMAT(Calendario[Date], "m")
# ```

# %% [markdown]
# ```
# Mes01 = FORMAT(Calendario[Date], "mm")
# ```

# %% [markdown]
# ```
# MesAbr = FORMAT(Calendario[Date], "mmm")
# ```

# %% [markdown]
# ```
# Mes en abreviatura en mayúsculas = UPPER(FORMAT(Calendario[Date], "mmm"))
# ```

# %% [markdown]
# ```
# MesAbr = UPPER(LEFT(FORMAT(Calendario[Date], "mmm"), 1)) & RIGHT(FORMAT(Calendario[Date], "mmm"),2)
# ```

# %% [markdown]
# ```
# Mes = FORMAT(Calendario[Date], "mmmm")
# ```

# %% [markdown]
# ```
# Mes en Mayúsculas = UPPER(FORMAT(Calendario[Date], "mmmm"))
# ```

# %% [markdown]
# ```
# Mes = LEFT(UPPER(FORMAT(Calendario[Date], "mmmm")),1) & RIGHT(LOWER(FORMAT(Calendario[Date], "mmmm")),LEN(FORMAT(Calendario[Date], "mmmm"))-1)
# ```

# %% [markdown]
# ```
# MesNum = MONTH(Calendario[Date])
# ```

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Día1 = FORMAT(Calendario[Date], "d")
# ```

# %% [markdown]
# ```
# Día01 = FORMAT(Calendario[Date], "dd")
# ```

# %% [markdown]
# ```
# DiaAbr = FORMAT(Calendario[Date], "ddd")
# ```

# %% [markdown]
# ```
# Dia = FORMAT(Calendario[Date], "dddd")
# ```

# %% [markdown]
# ```
# DiaNum = WEEKDAY(Calendario[Date])
# ```

# %% [markdown]
# ```
# Trimestre = "T-" & ROUNDUP(MONTH(Calendario[Date])/3, 0)
# ```

# %% [markdown]
# ```
# Trimestre2 = "T-"&QUARTER(Calendario[Date])
# ```

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Dia = UPPER(LEFT(FORMAT(Calendario[Date], "dddd"),1)) & RIGHT(FORMAT(Calendario[Date], "dddd"), LEN(FORMAT(Calendario[Date], "dddd"))-1)
# ```

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Calendario =
# ADDCOLUMNS
# (
#     CALENDAR
#     (
#         FIRSTDATE(Factura[fec_fac_dt]),
#         LASTDATE(Factura[fec_fac_dt])
#     ),
#     "Año", YEAR([Date]),
#     "Semestre", "S-" & ROUNDUP(MONTH([Date])/6,0),
#     "Trimestre", "T-" & ROUNDUP(MONTH([Date])/3,0),
#     "Mes",
#     UPPER(LEFT(FORMAT([Date], "MMMM"),1)) &
#     RIGHT(FORMAT([Date], "MMMM"), LEN(FORMAT([Date], "MMMM"))-1),
#     "MesNum", MONTH([Date]),
#     "Día",
#     UPPER(LEFT(FORMAT([Date], "DDDD"),1)) &
#     RIGHT(FORMAT([Date], "DDDD"), LEN(FORMAT([Date], "DDDD"))-1),
#     "DíaNum", WEEKDAY([Date], 2)
# )
# ```

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Calendario =
# ADDCOLUMNS
# (
#     CALENDAR
#     (
#         FIRSTDATE(Factura[fec_fac_dt]),
#         LASTDATE(Factura[fec_fac_dt])
#     ),
#     "Año", YEAR([Date]),
#     "Semestre", "S-" & ROUNDUP(MONTH([Date])/6,0),
#     "Trimestre", "T-" & ROUNDUP(MONTH([Date])/3,0),
#     "Mes",
#     UPPER(LEFT(FORMAT([Date], "MMMM"),1)) &
#     RIGHT(FORMAT([Date], "MMMM"), LEN(FORMAT([Date], "MMMM"))-1),
#     "MesNum", MONTH([Date]),
#     "SemanaAño", WEEKNUM([Date],2),
#     "Día",
#     UPPER(LEFT(FORMAT([Date], "DDDD"),1)) &
#     RIGHT(FORMAT([Date], "DDDD"), LEN(FORMAT([Date], "DDDD"))-1),
#     "DíaNum", WEEKDAY([Date], 2)
# )
# ```

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)
